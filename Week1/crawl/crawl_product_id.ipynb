# %% [markdown]
# CRAWL PRODUCT_ID FROM TIKI

# %%
import requests 
import pandas as pd

# %%
cookie = {
    "_trackity": "c2c1c5f3-221b-925b-b269-5d1418b3b23c",
    "delivery_zone": "Vk4wMzkwMDYwMDE=",
    "TOKENS": '{"access_token":"zLioEutP5FTrURfb0VJ8YvjIsW4mQZpD","expires_in":157680000,"expires_at":1917274590037,"guest_token":"zLioEutP5FTrURfb0VJ8YvjIsW4mQZpD"}',
    "_gcl_gs": "2.1.k1$i1759594588$u165506106",
    "_ga": "GA1.1.1128342722.1759594595",
    "_gcl_au": "1.1.1191301073.1759594599",
    "_gcl_aw": "GCL.1759594600.CjwKCAjwi4PHBhA-EiwAnjTHua-xkFbV1X4HfNN5ShgOKxyDj5PSJQYnNQfvCGodspg8-4aNJQ-jaRoCgF8QAvD_BwE",
    "_fbp": "fb.1.1759594601180.792040364863313916",
    "_tt_enable_cookie": "1",
    "_ttp": "01K6R05PVSHVAHZ8T1EFS2NX8G_.tt.1",
    "__utm": "source%3Dgoogle%7Cmedium%3Dcpc%7Ccampaign%3DSEA_NBR_GGL_PMA_DAP_ALL_VN_ALL_UNK_UNK_C.PMAX_X.22956852689_Y.185206935272_V._W.DT_A._O.CIR",
    "__iid": "749",
    "__su": "0",
    "__RC": "4",
    "__R": "1",
    "tiki_client_id": "1128342722.1759594595",
    "_hjSessionUser_522327": "eyJpZCI6ImRiNDU0NjgzLTkwYmYtNWQ1ZC1iOGViLWQzODFmZDgxNGI1YyIsImNyZWF0ZWQiOjE3NTk1OTQ2MDA3NTUsImV4aXN0aW5nIjp0cnVlfQ==",
    "__tb": "0",
    "__IP": "0",
    "_hjSession_522327": "eyJpZCI6Ijk4MDQ3NDFmLTU4MzYtNDNlNS1iOTJiLTZjZmEzZGJhYjMwMyIsImMiOjE3NTk2MzEyMTkwOTMsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=",
    "cto_bundle": "9IBdQl8wWVBhbFFzJTJGR05LJTJCV0VvVGFmRE9GbTdXZXpDamZNRnpvVHBwdkxjeGp1bGdsJTJGVTN2MUloaGxlbHZnd3VmT1htRkQ5VkMwcjZybWNoN2NKbFRTdFUlMkZ0UlNDTEF3WjVSOFF2ZldRMndhTjIwWk5ZUzIlMkJPVjIyRUdLOUhPWUpXY25nMFBFOWcybUsyWUpJZkZoMnZYMHpnJTNEJTNE",
    "ttcsid": "1759631218274::IlFkBzsb9wGT9VzdbXTS.3.1759631628198.0",
    "ttcsid_D031T03C77UFNM54TPR0": "1759631218274::vn279TXq3fbf6NzgDToD.3.1759631628198.0",
    "__uif": "__uid%3A8601573712242244050%7C__ui%3A-1%7C__create%3A1759594601",
    "_ga_S9GLR1RQFJ": "GS2.1.s1759631234$o3$g1$t1759631638$j41$l0$h0",
    "amp_99d374": "M8EkLCDZ3H7jE2z924zwQb...1j6p336ge.1j6p3fvtg.4g.5c.9s"
}

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'vi,en-US;q=0.9,en;q=0.8,fr-FR;q=0.7,fr;q=0.6',
    'Referer': 'https://tiki.vn/?src=header_tiki',
    'x-guest-token': 'zLioEutP5FTrURfb0VJ8YvjIsW4mQZpD',
    'Connection': 'keep-alive',
    'TE': 'Trailers',
    
}

# %%
params = {
    "limit": "40",
    "include": "advertisement",
    "aggregations": "2",
    "version": "home-persionalized",
    "trackity_id": "c2c1c5f3-221b-925b-b269-5d1418b3b23c",
    "category": "8322",
    "page": "1",
    "urlKey": "nha-sach-tiki"
}

# %%
product_id = []

# %%
for i in range(1,21) :
    params['page'] = i
    response = requests.get('https://tiki.vn/api/personalish/v1/blocks/listings' , headers = headers , params = params , cookies = cookie )   # lấy api từ web tiki
    if response.status_code == 200 :
        print("request accept !!")
        for record in response.json().get('data') :
            product_id.append({'id' : record.get('id')})
# Out:
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!
# request accept !!

# %%
df = pd.DataFrame(product_id)

# %%
df.head(10)
# Out:
#           id
# 0   25728855
# 1     601472
# 2  277412034
# 3  109515304
# 4   23416722
# 5  278159875
# 6  278150175
# 7  278101824
# 8  277891027
# 9  277809376

# %%
df.to_csv(r"D:\VS-workspace\Week1\dataset\product_id.csv")
